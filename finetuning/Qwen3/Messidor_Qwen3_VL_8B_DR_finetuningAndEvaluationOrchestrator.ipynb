# %%
import sys, subprocess

def run_live(cmd):
    p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
    for line in p.stdout:
        print(line, end="")
    rc = p.wait()
    if rc != 0:
        raise subprocess.CalledProcessError(rc, cmd)

TRAIN_PY = r"C:\Users\Mohammad\Documents\train_dr_qwen3vl_runsave.py"

SPLIT_DIR = r"C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10"
TRAIN_CSV = rf"{SPLIT_DIR}\train_split.csv"
VAL_CSV   = rf"{SPLIT_DIR}\val_split.csv"
TEST_CSV  = rf"{SPLIT_DIR}\test_split.csv"

IMAGE_DIR = r"C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\images"

TEMP_OUTPUT_DIR = rf"{SPLIT_DIR}\temp_training_output"
RUNS_ROOT       = rf"{SPLIT_DIR}\runs"
CACHE_DIR       = rf"{SPLIT_DIR}\cache"

cmd = [
    sys.executable, "-u", TRAIN_PY,
    "--csv_path", TRAIN_CSV,
    "--val_csv", VAL_CSV,
    "--test_csv", TEST_CSV,
    "--image_dir", IMAGE_DIR,
    "--ext", ".png",
    "--img_size", "512",

    "--model_name", "unsloth/Qwen3-VL-8B-Instruct-unsloth-bnb-4bit",
    "--output_dir", TEMP_OUTPUT_DIR,
    "--runs_root", RUNS_ROOT,

    "--cache_dir", CACHE_DIR,
    "--preproc_num_proc", "1",

    "--epochs", "50",
    "--batch_size", "4",
    "--grad_accum", "2",
    "--lr", "5e-4",
    "--warmup_steps", "20",
    "--max_length", "2048",

    "--lora_r", "16",
    "--lora_alpha", "16",
    "--lora_dropout", "0.05",

    "--eval_strategy", "epoch",
    "--save_strategy", "epoch",
    "--save_total_limit", "2",

    "--early_stopping",
    "--early_stopping_patience", "4",
    "--early_stopping_threshold", "0.0",

    "--load_in_4bit",
]

run_live(cmd)
# Out:
# Unsloth: Will patch your computer to enable 2x faster free finetuning.
# W0402 11:04:40.403000 2460 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# Unsloth: Your Flash Attention 2 installation seems to be broken?
# A possible explanation is you have a new CUDA version which isn't
# yet compatible with FA2? Please file a ticket to Unsloth or FA2.
# We shall now use Xformers instead, which does not have any performance hits!
# We found this negligible impact by benchmarking on 1x A100.
# Unsloth Zoo will now patch everything to make training faster!
# [INFO] Building datasets.
# [INFO] Loading cached datasets from: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\cache\dr_qwen3vl_98fc8ef293f6796d
# [INFO] Train rows: 846
# [INFO] Val rows:   105
# [INFO] Test rows:  106
# [INFO] Loading model.
# ==((====))==  Unsloth 2026.2.1: Fast Qwen3_Vl patching. Transformers: 5.3.0.dev0.
#    \\   /|    NVIDIA GeForce RTX 5070 Ti. Num GPUs = 1. Max memory: 15.92 GB. Platform: Windows.
# O^O/ \_/ \    Torch: 2.10.0+cu130. CUDA: 12.0. CUDA Toolkit: 13.0. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
#
# Loading weights:   0%|          | 0/750 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/750 [00:00<?, ?it/s, Materializing param=lm_head.weight]
# Loading weights:   0%|          | 1/750 [00:00<?, ?it/s, Materializing param=lm_head.weight]
# Loading weights:   0%|          | 2/750 [00:00<01:20,  9.35it/s, Materializing param=lm_head.weight]
# Loading weights:   0%|          | 2/750 [00:00<01:20,  9.35it/s, Materializing param=model.language_model.embed_tokens.weight]
# Loading weights:   0%|          | 2/750 [00:00<01:20,  9.35it/s, Materializing param=model.language_model.embed_tokens.weight]
# Loading weights:   0%|          | 3/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.embed_tokens.weight]
# Loading weights:   0%|          | 3/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.layers.0.input_layernorm.weight]
# Loading weights:   0%|          | 3/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.layers.0.input_layernorm.weight]
# Loading weights:   1%|          | 4/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.layers.0.mlp.down_proj.weight]
# Loading weights:   1%|          | 4/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.layers.0.mlp.down_proj.weight]
# Loading weights:   1%|          | 5/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.layers.0.mlp.gate_proj.weight]
# Loading weights:   1%|          | 5/750 [00:00<02:36,  4.77it/s, Materializing param=model.language_model.layers.0.mlp.gate_proj.weight]
# Loading weights:   1%|          | 6/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.mlp.up_proj.weight]
# Loading weights:   1%|          | 6/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.mlp.up_proj.weight]
# Loading weights:   1%|          | 7/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.post_attention_layernorm.weight]
# Loading weights:   1%|          | 7/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.post_attention_layernorm.weight]
# Loading weights:   1%|1         | 8/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.k_norm.weight]
# Loading weights:   1%|1         | 8/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.k_norm.weight]
# Loading weights:   1%|1         | 9/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.k_proj.weight]
# Loading weights:   1%|1         | 9/750 [00:00<02:35,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.k_proj.weight]
# Loading weights:   1%|1         | 10/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.o_proj.weight]
# Loading weights:   1%|1         | 10/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.o_proj.weight]
# Loading weights:   1%|1         | 11/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.q_norm.weight]
# Loading weights:   1%|1         | 11/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.q_norm.weight]
# Loading weights:   2%|1         | 12/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.q_proj.weight]
# Loading weights:   2%|1         | 12/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.q_proj.weight]
# Loading weights:   2%|1         | 13/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.v_proj.weight]
# Loading weights:   2%|1         | 13/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.0.self_attn.v_proj.weight]
# Loading weights:   2%|1         | 14/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.1.input_layernorm.weight]
# Loading weights:   2%|1         | 14/750 [00:00<02:34,  4.77it/s, Materializing param=model.language_model.layers.1.input_layernorm.weight]
# Loading weights:   2%|2         | 15/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.mlp.down_proj.weight]
# Loading weights:   2%|2         | 15/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.mlp.down_proj.weight]
# Loading weights:   2%|2         | 16/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.mlp.gate_proj.weight]
# Loading weights:   2%|2         | 16/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.mlp.gate_proj.weight]
# Loading weights:   2%|2         | 17/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.mlp.up_proj.weight]
# Loading weights:   2%|2         | 17/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.mlp.up_proj.weight]
# Loading weights:   2%|2         | 18/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.post_attention_layernorm.weight]
# Loading weights:   2%|2         | 18/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.post_attention_layernorm.weight]
# Loading weights:   3%|2         | 19/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.k_norm.weight]
# Loading weights:   3%|2         | 19/750 [00:00<02:33,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.k_norm.weight]
# Loading weights:   3%|2         | 20/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.k_proj.weight]
# Loading weights:   3%|2         | 20/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.k_proj.weight]
# Loading weights:   3%|2         | 21/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.o_proj.weight]
# Loading weights:   3%|2         | 21/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.o_proj.weight]
# Loading weights:   3%|2         | 22/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.q_norm.weight]
# Loading weights:   3%|2         | 22/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.q_norm.weight]
# Loading weights:   3%|3         | 23/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.q_proj.weight]
# Loading weights:   3%|3         | 23/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.q_proj.weight]
# Loading weights:   3%|3         | 24/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.v_proj.weight]
# Loading weights:   3%|3         | 24/750 [00:00<02:32,  4.77it/s, Materializing param=model.language_model.layers.1.self_attn.v_proj.weight]
# Loading weights:   3%|3         | 25/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.input_layernorm.weight]
# Loading weights:   3%|3         | 25/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.input_layernorm.weight]
# Loading weights:   3%|3         | 26/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.mlp.down_proj.weight]
# Loading weights:   3%|3         | 26/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.mlp.down_proj.weight]
# Loading weights:   4%|3         | 27/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.mlp.gate_proj.weight]
# Loading weights:   4%|3         | 27/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.mlp.gate_proj.weight]
# Loading weights:   4%|3         | 28/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.mlp.up_proj.weight]
# Loading weights:   4%|3         | 28/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.mlp.up_proj.weight]
# Loading weights:   4%|3         | 29/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.post_attention_layernorm.weight]
# Loading weights:   4%|3         | 29/750 [00:00<02:31,  4.77it/s, Materializing param=model.language_model.layers.2.post_attention_layernorm.weight]
# Loading weights:   4%|4         | 30/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.k_norm.weight]
# Loading weights:   4%|4         | 30/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.k_norm.weight]
# Loading weights:   4%|4         | 31/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.k_proj.weight]
# Loading weights:   4%|4         | 31/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.k_proj.weight]
# Loading weights:   4%|4         | 32/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.o_proj.weight]
# Loading weights:   4%|4         | 32/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.o_proj.weight]
# Loading weights:   4%|4         | 33/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.q_norm.weight]
# Loading weights:   4%|4         | 33/750 [00:00<02:30,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.q_norm.weight]
# Loading weights:   5%|4         | 34/750 [00:00<02:29,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.q_proj.weight]
# Loading weights:   5%|4         | 34/750 [00:00<02:29,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.q_proj.weight]
# Loading weights:   5%|4         | 35/750 [00:00<02:29,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.v_proj.weight]
# Loading weights:   5%|4         | 35/750 [00:00<02:29,  4.77it/s, Materializing param=model.language_model.layers.2.self_attn.v_proj.weight]
# Loading weights:   5%|4         | 36/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.2.self_attn.v_proj.weight]
# Loading weights:   5%|4         | 36/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.input_layernorm.weight]
# Loading weights:   5%|4         | 36/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.input_layernorm.weight]
# Loading weights:   5%|4         | 37/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.mlp.down_proj.weight]
# Loading weights:   5%|4         | 37/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.mlp.down_proj.weight]
# Loading weights:   5%|5         | 38/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.mlp.gate_proj.weight]
# Loading weights:   5%|5         | 38/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.mlp.gate_proj.weight]
# Loading weights:   5%|5         | 39/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.mlp.up_proj.weight]
# Loading weights:   5%|5         | 39/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.mlp.up_proj.weight]
# Loading weights:   5%|5         | 40/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.post_attention_layernorm.weight]
# Loading weights:   5%|5         | 40/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.post_attention_layernorm.weight]
# Loading weights:   5%|5         | 41/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.k_norm.weight]
# Loading weights:   5%|5         | 41/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.k_norm.weight]
# Loading weights:   6%|5         | 42/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.k_proj.weight]
# Loading weights:   6%|5         | 42/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.k_proj.weight]
# Loading weights:   6%|5         | 43/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.o_proj.weight]
# Loading weights:   6%|5         | 43/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.o_proj.weight]
# Loading weights:   6%|5         | 44/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.q_norm.weight]
# Loading weights:   6%|5         | 44/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.q_norm.weight]
# Loading weights:   6%|6         | 45/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.q_proj.weight]
# Loading weights:   6%|6         | 45/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.q_proj.weight]
# Loading weights:   6%|6         | 46/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.v_proj.weight]
# Loading weights:   6%|6         | 46/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.3.self_attn.v_proj.weight]
# Loading weights:   6%|6         | 47/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.input_layernorm.weight]
# Loading weights:   6%|6         | 47/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.input_layernorm.weight]
# Loading weights:   6%|6         | 48/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.mlp.down_proj.weight]
# Loading weights:   6%|6         | 48/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.mlp.down_proj.weight]
# Loading weights:   7%|6         | 49/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.mlp.gate_proj.weight]
# Loading weights:   7%|6         | 49/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.mlp.gate_proj.weight]
# Loading weights:   7%|6         | 50/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.mlp.up_proj.weight]
# Loading weights:   7%|6         | 50/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.mlp.up_proj.weight]
# Loading weights:   7%|6         | 51/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.post_attention_layernorm.weight]
# Loading weights:   7%|6         | 51/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.post_attention_layernorm.weight]
# Loading weights:   7%|6         | 52/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.k_norm.weight]
# Loading weights:   7%|6         | 52/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.k_norm.weight]
# Loading weights:   7%|7         | 53/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.k_proj.weight]
# Loading weights:   7%|7         | 53/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.k_proj.weight]
# Loading weights:   7%|7         | 54/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.o_proj.weight]
# Loading weights:   7%|7         | 54/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.o_proj.weight]
# Loading weights:   7%|7         | 55/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.q_norm.weight]
# Loading weights:   7%|7         | 55/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.q_norm.weight]
# Loading weights:   7%|7         | 56/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.q_proj.weight]
# Loading weights:   7%|7         | 56/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.q_proj.weight]
# Loading weights:   8%|7         | 57/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.v_proj.weight]
# Loading weights:   8%|7         | 57/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.4.self_attn.v_proj.weight]
# Loading weights:   8%|7         | 58/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.input_layernorm.weight]
# Loading weights:   8%|7         | 58/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.input_layernorm.weight]
# Loading weights:   8%|7         | 59/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.mlp.down_proj.weight]
# Loading weights:   8%|7         | 59/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.mlp.down_proj.weight]
# Loading weights:   8%|8         | 60/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.mlp.gate_proj.weight]
# Loading weights:   8%|8         | 60/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.mlp.gate_proj.weight]
# Loading weights:   8%|8         | 61/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.mlp.up_proj.weight]
# Loading weights:   8%|8         | 61/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.mlp.up_proj.weight]
# Loading weights:   8%|8         | 62/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.post_attention_layernorm.weight]
# Loading weights:   8%|8         | 62/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.post_attention_layernorm.weight]
# Loading weights:   8%|8         | 63/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.self_attn.k_norm.weight]
# Loading weights:   8%|8         | 63/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.self_attn.k_norm.weight]
# Loading weights:   9%|8         | 64/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.self_attn.k_proj.weight]
# Loading weights:   9%|8         | 64/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.self_attn.k_proj.weight]
# Loading weights:   9%|8         | 65/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.self_attn.o_proj.weight]
# Loading weights:   9%|8         | 65/750 [00:00<00:09, 75.76it/s, Materializing param=model.language_model.layers.5.self_attn.o_proj.weight]
# Loading weights:   9%|8         | 66/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.o_proj.weight]
# Loading weights:   9%|8         | 66/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.q_norm.weight]
# Loading weights:   9%|8         | 66/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.q_norm.weight]
# Loading weights:   9%|8         | 67/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.q_proj.weight]
# Loading weights:   9%|8         | 67/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.q_proj.weight]
# Loading weights:   9%|9         | 68/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.v_proj.weight]
# Loading weights:   9%|9         | 68/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.5.self_attn.v_proj.weight]
# Loading weights:   9%|9         | 69/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.input_layernorm.weight]
# Loading weights:   9%|9         | 69/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.input_layernorm.weight]
# Loading weights:   9%|9         | 70/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.mlp.down_proj.weight]
# Loading weights:   9%|9         | 70/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.mlp.down_proj.weight]
# Loading weights:   9%|9         | 71/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.mlp.gate_proj.weight]
# Loading weights:   9%|9         | 71/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.mlp.gate_proj.weight]
# Loading weights:  10%|9         | 72/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.mlp.up_proj.weight]
# Loading weights:  10%|9         | 72/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.mlp.up_proj.weight]
# Loading weights:  10%|9         | 73/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.post_attention_layernorm.weight]
# Loading weights:  10%|9         | 73/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.post_attention_layernorm.weight]
# Loading weights:  10%|9         | 74/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.k_norm.weight]
# Loading weights:  10%|9         | 74/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.k_norm.weight]
# Loading weights:  10%|#         | 75/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.k_proj.weight]
# Loading weights:  10%|#         | 75/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.k_proj.weight]
# Loading weights:  10%|#         | 76/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.o_proj.weight]
# Loading weights:  10%|#         | 76/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.o_proj.weight]
# Loading weights:  10%|#         | 77/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.q_norm.weight]
# Loading weights:  10%|#         | 77/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.q_norm.weight]
# Loading weights:  10%|#         | 78/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.q_proj.weight]
# Loading weights:  10%|#         | 78/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.q_proj.weight]
# Loading weights:  11%|#         | 79/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.v_proj.weight]
# Loading weights:  11%|#         | 79/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.6.self_attn.v_proj.weight]
# Loading weights:  11%|#         | 80/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.input_layernorm.weight]
# Loading weights:  11%|#         | 80/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.input_layernorm.weight]
# Loading weights:  11%|#         | 81/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.mlp.down_proj.weight]
# Loading weights:  11%|#         | 81/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.mlp.down_proj.weight]
# Loading weights:  11%|#         | 82/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.mlp.gate_proj.weight]
# Loading weights:  11%|#         | 82/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.mlp.gate_proj.weight]
# Loading weights:  11%|#1        | 83/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.mlp.up_proj.weight]
# Loading weights:  11%|#1        | 83/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.mlp.up_proj.weight]
# Loading weights:  11%|#1        | 84/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.post_attention_layernorm.weight]
# Loading weights:  11%|#1        | 84/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.post_attention_layernorm.weight]
# Loading weights:  11%|#1        | 85/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.k_norm.weight]
# Loading weights:  11%|#1        | 85/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.k_norm.weight]
# Loading weights:  11%|#1        | 86/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.k_proj.weight]
# Loading weights:  11%|#1        | 86/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.k_proj.weight]
# Loading weights:  12%|#1        | 87/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.o_proj.weight]
# Loading weights:  12%|#1        | 87/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.o_proj.weight]
# Loading weights:  12%|#1        | 88/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.q_norm.weight]
# Loading weights:  12%|#1        | 88/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.q_norm.weight]
# Loading weights:  12%|#1        | 89/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.q_proj.weight]
# Loading weights:  12%|#1        | 89/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.q_proj.weight]
# Loading weights:  12%|#2        | 90/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.v_proj.weight]
# Loading weights:  12%|#2        | 90/750 [00:00<00:05, 124.05it/s, Materializing param=model.language_model.layers.7.self_attn.v_proj.weight]
# Loading weights:  12%|#2        | 91/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.7.self_attn.v_proj.weight]
# Loading weights:  12%|#2        | 91/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.input_layernorm.weight]
# Loading weights:  12%|#2        | 91/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.input_layernorm.weight]
# Loading weights:  12%|#2        | 92/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.mlp.down_proj.weight]
# Loading weights:  12%|#2        | 92/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.mlp.down_proj.weight]
# Loading weights:  12%|#2        | 93/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.mlp.gate_proj.weight]
# Loading weights:  12%|#2        | 93/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.mlp.gate_proj.weight]
# Loading weights:  13%|#2        | 94/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.mlp.up_proj.weight]
# Loading weights:  13%|#2        | 94/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.mlp.up_proj.weight]
# Loading weights:  13%|#2        | 95/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.post_attention_layernorm.weight]
# Loading weights:  13%|#2        | 95/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.post_attention_layernorm.weight]
# Loading weights:  13%|#2        | 96/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.k_norm.weight]
# Loading weights:  13%|#2        | 96/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.k_norm.weight]
# Loading weights:  13%|#2        | 97/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.k_proj.weight]
# Loading weights:  13%|#2        | 97/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.k_proj.weight]
# Loading weights:  13%|#3        | 98/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.o_proj.weight]
# Loading weights:  13%|#3        | 98/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.o_proj.weight]
# Loading weights:  13%|#3        | 99/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.q_norm.weight]
# Loading weights:  13%|#3        | 99/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.q_norm.weight]
# Loading weights:  13%|#3        | 100/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.q_proj.weight]
# Loading weights:  13%|#3        | 100/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.q_proj.weight]
# Loading weights:  13%|#3        | 101/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.v_proj.weight]
# Loading weights:  13%|#3        | 101/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.8.self_attn.v_proj.weight]
# Loading weights:  14%|#3        | 102/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.input_layernorm.weight]
# Loading weights:  14%|#3        | 102/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.input_layernorm.weight]
# Loading weights:  14%|#3        | 103/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.mlp.down_proj.weight]
# Loading weights:  14%|#3        | 103/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.mlp.down_proj.weight]
# Loading weights:  14%|#3        | 104/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.mlp.gate_proj.weight]
# Loading weights:  14%|#3        | 104/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.mlp.gate_proj.weight]
# Loading weights:  14%|#4        | 105/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.mlp.up_proj.weight]
# Loading weights:  14%|#4        | 105/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.mlp.up_proj.weight]
# Loading weights:  14%|#4        | 106/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.post_attention_layernorm.weight]
# Loading weights:  14%|#4        | 106/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.post_attention_layernorm.weight]
# Loading weights:  14%|#4        | 107/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.k_norm.weight]
# Loading weights:  14%|#4        | 107/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.k_norm.weight]
# Loading weights:  14%|#4        | 108/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.k_proj.weight]
# Loading weights:  14%|#4        | 108/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.k_proj.weight]
# Loading weights:  15%|#4        | 109/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.o_proj.weight]
# Loading weights:  15%|#4        | 109/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.o_proj.weight]
# Loading weights:  15%|#4        | 110/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.q_norm.weight]
# Loading weights:  15%|#4        | 110/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.q_norm.weight]
# Loading weights:  15%|#4        | 111/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.q_proj.weight]
# Loading weights:  15%|#4        | 111/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.q_proj.weight]
# Loading weights:  15%|#4        | 112/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.v_proj.weight]
# Loading weights:  15%|#4        | 112/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.9.self_attn.v_proj.weight]
# Loading weights:  15%|#5        | 113/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.input_layernorm.weight]
# Loading weights:  15%|#5        | 113/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.input_layernorm.weight]
# Loading weights:  15%|#5        | 114/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.mlp.down_proj.weight]
# Loading weights:  15%|#5        | 114/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.mlp.down_proj.weight]
# Loading weights:  15%|#5        | 115/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.mlp.gate_proj.weight]
# Loading weights:  15%|#5        | 115/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.mlp.gate_proj.weight]
# Loading weights:  15%|#5        | 116/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.mlp.up_proj.weight]
# Loading weights:  15%|#5        | 116/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.mlp.up_proj.weight]
# Loading weights:  16%|#5        | 117/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.post_attention_layernorm.weight]
# Loading weights:  16%|#5        | 117/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.post_attention_layernorm.weight]
# Loading weights:  16%|#5        | 118/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.k_norm.weight]
# Loading weights:  16%|#5        | 118/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.k_norm.weight]
# Loading weights:  16%|#5        | 119/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.k_proj.weight]
# Loading weights:  16%|#5        | 119/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.k_proj.weight]
# Loading weights:  16%|#6        | 120/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.o_proj.weight]
# Loading weights:  16%|#6        | 120/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.o_proj.weight]
# Loading weights:  16%|#6        | 121/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.q_norm.weight]
# Loading weights:  16%|#6        | 121/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.q_norm.weight]
# Loading weights:  16%|#6        | 122/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.q_proj.weight]
# Loading weights:  16%|#6        | 122/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.q_proj.weight]
# Loading weights:  16%|#6        | 123/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.v_proj.weight]
# Loading weights:  16%|#6        | 123/750 [00:00<00:04, 152.79it/s, Materializing param=model.language_model.layers.10.self_attn.v_proj.weight]
# Loading weights:  17%|#6        | 124/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.10.self_attn.v_proj.weight]
# Loading weights:  17%|#6        | 124/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.input_layernorm.weight]
# Loading weights:  17%|#6        | 124/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.input_layernorm.weight]
# Loading weights:  17%|#6        | 125/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.mlp.down_proj.weight]
# Loading weights:  17%|#6        | 125/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.mlp.down_proj.weight]
# Loading weights:  17%|#6        | 126/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.mlp.gate_proj.weight]
# Loading weights:  17%|#6        | 126/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.mlp.gate_proj.weight]
# Loading weights:  17%|#6        | 127/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.mlp.up_proj.weight]
# Loading weights:  17%|#6        | 127/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.mlp.up_proj.weight]
# Loading weights:  17%|#7        | 128/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.post_attention_layernorm.weight]
# Loading weights:  17%|#7        | 128/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.post_attention_layernorm.weight]
# Loading weights:  17%|#7        | 129/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.k_norm.weight]
# Loading weights:  17%|#7        | 129/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.k_norm.weight]
# Loading weights:  17%|#7        | 130/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.k_proj.weight]
# Loading weights:  17%|#7        | 130/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.k_proj.weight]
# Loading weights:  17%|#7        | 131/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.o_proj.weight]
# Loading weights:  17%|#7        | 131/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.o_proj.weight]
# Loading weights:  18%|#7        | 132/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.q_norm.weight]
# Loading weights:  18%|#7        | 132/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.q_norm.weight]
# Loading weights:  18%|#7        | 133/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.q_proj.weight]
# Loading weights:  18%|#7        | 133/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.q_proj.weight]
# Loading weights:  18%|#7        | 134/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.v_proj.weight]
# Loading weights:  18%|#7        | 134/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.11.self_attn.v_proj.weight]
# Loading weights:  18%|#8        | 135/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.input_layernorm.weight]
# Loading weights:  18%|#8        | 135/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.input_layernorm.weight]
# Loading weights:  18%|#8        | 136/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.mlp.down_proj.weight]
# Loading weights:  18%|#8        | 136/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.mlp.down_proj.weight]
# Loading weights:  18%|#8        | 137/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.mlp.gate_proj.weight]
# Loading weights:  18%|#8        | 137/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.mlp.gate_proj.weight]
# Loading weights:  18%|#8        | 138/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.mlp.up_proj.weight]
# Loading weights:  18%|#8        | 138/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.mlp.up_proj.weight]
# Loading weights:  19%|#8        | 139/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.post_attention_layernorm.weight]
# Loading weights:  19%|#8        | 139/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.post_attention_layernorm.weight]
# Loading weights:  19%|#8        | 140/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.k_norm.weight]
# Loading weights:  19%|#8        | 140/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.k_norm.weight]
# Loading weights:  19%|#8        | 141/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.k_proj.weight]
# Loading weights:  19%|#8        | 141/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.k_proj.weight]
# Loading weights:  19%|#8        | 142/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.o_proj.weight]
# Loading weights:  19%|#8        | 142/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.o_proj.weight]
# Loading weights:  19%|#9        | 143/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.q_norm.weight]
# Loading weights:  19%|#9        | 143/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.q_norm.weight]
# Loading weights:  19%|#9        | 144/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.q_proj.weight]
# Loading weights:  19%|#9        | 144/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.q_proj.weight]
# Loading weights:  19%|#9        | 145/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.v_proj.weight]
# Loading weights:  19%|#9        | 145/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.12.self_attn.v_proj.weight]
# Loading weights:  19%|#9        | 146/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.input_layernorm.weight]
# Loading weights:  19%|#9        | 146/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.input_layernorm.weight]
# Loading weights:  20%|#9        | 147/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.mlp.down_proj.weight]
# Loading weights:  20%|#9        | 147/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.mlp.down_proj.weight]
# Loading weights:  20%|#9        | 148/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.mlp.gate_proj.weight]
# Loading weights:  20%|#9        | 148/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.mlp.gate_proj.weight]
# Loading weights:  20%|#9        | 149/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.mlp.up_proj.weight]
# Loading weights:  20%|#9        | 149/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.mlp.up_proj.weight]
# Loading weights:  20%|##        | 150/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.post_attention_layernorm.weight]
# Loading weights:  20%|##        | 150/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.post_attention_layernorm.weight]
# Loading weights:  20%|##        | 151/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.k_norm.weight]
# Loading weights:  20%|##        | 151/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.k_norm.weight]
# Loading weights:  20%|##        | 152/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.k_proj.weight]
# Loading weights:  20%|##        | 152/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.k_proj.weight]
# Loading weights:  20%|##        | 153/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.o_proj.weight]
# Loading weights:  20%|##        | 153/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.o_proj.weight]
# Loading weights:  21%|##        | 154/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.q_norm.weight]
# Loading weights:  21%|##        | 154/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.q_norm.weight]
# Loading weights:  21%|##        | 155/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.q_proj.weight]
# Loading weights:  21%|##        | 155/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.q_proj.weight]
# Loading weights:  21%|##        | 156/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.v_proj.weight]
# Loading weights:  21%|##        | 156/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.13.self_attn.v_proj.weight]
# Loading weights:  21%|##        | 157/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.14.input_layernorm.weight]
# Loading weights:  21%|##        | 157/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.14.input_layernorm.weight]
# Loading weights:  21%|##1       | 158/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.14.mlp.down_proj.weight]
# Loading weights:  21%|##1       | 158/750 [00:01<00:03, 194.85it/s, Materializing param=model.language_model.layers.14.mlp.down_proj.weight]
# Loading weights:  21%|##1       | 159/750 [00:01<00:02, 234.58it/s, Materializing param=model.language_model.layers.14.mlp.down_proj.weight]
# Loading weights:  21%|##1       | 159/750 [00:01<00:02, 234.58it/s, Materializing param=model.language_model.layers.14.mlp.gate_proj.weight]
# Loading weights:  21%|##1       | 159/750 [00:01<00:02, 234.58it/s, Materializing param=model.language_model.layers.14.mlp.gate_proj.weight]
# Loading weights:  21%|##1       | 160/750 [00:01<00:02, 234.58it/s, Materializing param=model.language_model.layers.14.mlp.up_proj.weight]
# Loading weights:  21%|##1       | 160/750 [00:01<00:02, 234.58it/s, Materializing param=model.language_model.layers.14.mlp.up_proj.weight]
# Loading weights:  21%|##1       | 161/750 [00:01<00:02, 234.58it/s, Materializing param=model.language_model.layers.14.post_attention_layernorm.weight]
# ...
#   8%|7         | 410/5300 [20:59<3:49:29,  2.82s/it]
#
# {'loss': '0.01984', 'grad_norm': '0.008343', 'learning_rate': '0.0004632', 'epoch': '3.868'}
#
#   8%|7         | 410/5300 [20:59<3:49:29,  2.82s/it]
#   8%|7         | 411/5300 [21:02<3:49:16,  2.81s/it]
#   8%|7         | 412/5300 [21:05<3:48:52,  2.81s/it]
#   8%|7         | 413/5300 [21:08<3:55:57,  2.90s/it]
#   8%|7         | 414/5300 [21:11<3:53:35,  2.87s/it]
#   8%|7         | 415/5300 [21:13<3:52:24,  2.85s/it]
#
# {'loss': '0.02032', 'grad_norm': '0.0122', 'learning_rate': '0.0004627', 'epoch': '3.915'}
#
#   8%|7         | 415/5300 [21:13<3:52:24,  2.85s/it]
#   8%|7         | 416/5300 [21:16<3:51:19,  2.84s/it]
#   8%|7         | 417/5300 [21:19<3:50:03,  2.83s/it]
#   8%|7         | 418/5300 [21:22<3:49:14,  2.82s/it]
#   8%|7         | 419/5300 [21:25<3:48:54,  2.81s/it]
#   8%|7         | 420/5300 [21:27<3:48:20,  2.81s/it]
#
# {'loss': '0.02009', 'grad_norm': '0.009034', 'learning_rate': '0.0004622', 'epoch': '3.962'}
#
#   8%|7         | 420/5300 [21:27<3:48:20,  2.81s/it]
#   8%|7         | 421/5300 [21:30<3:48:13,  2.81s/it]
#   8%|7         | 422/5300 [21:33<3:56:20,  2.91s/it]
#   8%|7         | 423/5300 [21:36<3:53:33,  2.87s/it]
#   8%|8         | 424/5300 [21:38<3:37:27,  2.68s/it]
#
#   0%|          | 0/27 [00:00<?, ?it/s]
#
#   7%|7         | 2/27 [00:00<00:06,  4.13it/s]
#
#  11%|#1        | 3/27 [00:00<00:08,  2.82it/s]
#
#  15%|#4        | 4/27 [00:01<00:09,  2.47it/s]
#
#  19%|#8        | 5/27 [00:01<00:09,  2.30it/s]
#
#  22%|##2       | 6/27 [00:02<00:09,  2.21it/s]
#
#  26%|##5       | 7/27 [00:02<00:09,  2.13it/s]
#
#  30%|##9       | 8/27 [00:03<00:08,  2.11it/s]
#
#  33%|###3      | 9/27 [00:03<00:08,  2.07it/s]
#
#  37%|###7      | 10/27 [00:04<00:08,  2.06it/s]
#
#  41%|####      | 11/27 [00:04<00:07,  2.04it/s]
#
#  44%|####4     | 12/27 [00:05<00:07,  2.04it/s]
#
#  48%|####8     | 13/27 [00:05<00:06,  2.01it/s]
#
#  52%|#####1    | 14/27 [00:06<00:06,  2.03it/s]
#
#  56%|#####5    | 15/27 [00:06<00:05,  2.02it/s]
#
#  59%|#####9    | 16/27 [00:07<00:05,  2.02it/s]
#
#  63%|######2   | 17/27 [00:07<00:04,  2.02it/s]
#
#  67%|######6   | 18/27 [00:08<00:04,  2.03it/s]
#
#  70%|#######   | 19/27 [00:08<00:03,  2.01it/s]
#
#  74%|#######4  | 20/27 [00:09<00:03,  2.03it/s]
#
#  78%|#######7  | 21/27 [00:09<00:02,  2.02it/s]
#
#  81%|########1 | 22/27 [00:10<00:02,  2.03it/s]
#
#  85%|########5 | 23/27 [00:10<00:01,  2.00it/s]
#
#  89%|########8 | 24/27 [00:11<00:01,  2.02it/s]
#
#  93%|#########2| 25/27 [00:11<00:00,  2.01it/s]
#
#  96%|#########6| 26/27 [00:12<00:00,  2.05it/s]
#
# 100%|##########| 27/27 [00:12<00:00,  2.28it/s]
#
#
#
#
# {'eval_loss': '0.0203', 'eval_runtime': '13.07', 'eval_samples_per_second': '8.031', 'eval_steps_per_second': '2.065', 'epoch': '4'}
#
#   8%|8         | 424/5300 [21:51<3:37:27,  2.68s/it]
#
# 100%|##########| 27/27 [00:12<00:00,  2.28it/s]
#
#
#   8%|8         | 425/5300 [21:56<9:32:46,  7.05s/it]
#
# {'loss': '0.01966', 'grad_norm': '0.00899', 'learning_rate': '0.0004617', 'epoch': '4.009'}
#
#   8%|8         | 425/5300 [21:56<9:32:46,  7.05s/it]
#   8%|8         | 426/5300 [21:58<7:49:02,  5.77s/it]
#   8%|8         | 427/5300 [22:01<6:36:42,  4.88s/it]
#   8%|8         | 428/5300 [22:04<5:45:42,  4.26s/it]
#   8%|8         | 429/5300 [22:07<5:17:32,  3.91s/it]
#   8%|8         | 430/5300 [22:10<4:50:23,  3.58s/it]
#
# {'loss': '0.0198', 'grad_norm': '0.009605', 'learning_rate': '0.0004613', 'epoch': '4.057'}
#
#   8%|8         | 430/5300 [22:10<4:50:23,  3.58s/it]
#   8%|8         | 431/5300 [22:13<4:31:25,  3.34s/it]
#   8%|8         | 432/5300 [22:16<4:18:07,  3.18s/it]
#   8%|8         | 433/5300 [22:18<4:08:52,  3.07s/it]
#   8%|8         | 434/5300 [22:21<4:02:06,  2.99s/it]
#   8%|8         | 435/5300 [22:24<3:57:37,  2.93s/it]
#
# {'loss': '0.01981', 'grad_norm': '0.00782', 'learning_rate': '0.0004608', 'epoch': '4.104'}
#
#   8%|8         | 435/5300 [22:24<3:57:37,  2.93s/it]
#   8%|8         | 436/5300 [22:27<3:54:32,  2.89s/it]
#   8%|8         | 437/5300 [22:30<3:52:19,  2.87s/it]
#   8%|8         | 438/5300 [22:33<3:59:53,  2.96s/it]
#   8%|8         | 439/5300 [22:35<3:55:58,  2.91s/it]
#   8%|8         | 440/5300 [22:38<3:53:09,  2.88s/it]
#
# {'loss': '0.02013', 'grad_norm': '0.01451', 'learning_rate': '0.0004603', 'epoch': '4.151'}
#
#   8%|8         | 440/5300 [22:38<3:53:09,  2.88s/it]
#   8%|8         | 441/5300 [22:41<3:51:06,  2.85s/it]
#   8%|8         | 442/5300 [22:44<3:49:39,  2.84s/it]
#   8%|8         | 443/5300 [22:47<3:48:52,  2.83s/it]
#   8%|8         | 444/5300 [22:49<3:48:11,  2.82s/it]
#   8%|8         | 445/5300 [22:52<3:47:29,  2.81s/it]
#
# {'loss': '0.02037', 'grad_norm': '0.0118', 'learning_rate': '0.0004598', 'epoch': '4.198'}
#
#   8%|8         | 445/5300 [22:52<3:47:29,  2.81s/it]
#   8%|8         | 446/5300 [22:55<3:56:35,  2.92s/it]
#   8%|8         | 447/5300 [22:58<3:53:16,  2.88s/it]
#   8%|8         | 448/5300 [23:01<3:51:13,  2.86s/it]
#   8%|8         | 449/5300 [23:04<3:49:36,  2.84s/it]
#   8%|8         | 450/5300 [23:07<3:48:40,  2.83s/it]
#
# {'loss': '0.02008', 'grad_norm': '0.007543', 'learning_rate': '0.0004594', 'epoch': '4.245'}
#
#   8%|8         | 450/5300 [23:07<3:48:40,  2.83s/it]
#   9%|8         | 451/5300 [23:09<3:48:12,  2.82s/it]
#   9%|8         | 452/5300 [23:12<3:47:35,  2.82s/it]
#   9%|8         | 453/5300 [23:15<3:47:05,  2.81s/it]
#   9%|8         | 454/5300 [23:18<3:55:52,  2.92s/it]
#   9%|8         | 455/5300 [23:21<3:52:49,  2.88s/it]
#
# {'loss': '0.01983', 'grad_norm': '0.007769', 'learning_rate': '0.0004589', 'epoch': '4.292'}
#
#   9%|8         | 455/5300 [23:21<3:52:49,  2.88s/it]
#   9%|8         | 456/5300 [23:24<3:50:40,  2.86s/it]
#   9%|8         | 457/5300 [23:27<3:49:19,  2.84s/it]
#   9%|8         | 458/5300 [23:29<3:48:19,  2.83s/it]
#   9%|8         | 459/5300 [23:32<3:47:41,  2.82s/it]
#   9%|8         | 460/5300 [23:35<3:47:02,  2.81s/it]
#
# {'loss': '0.01993', 'grad_norm': '0.006955', 'learning_rate': '0.0004584', 'epoch': '4.34'}
#
#   9%|8         | 460/5300 [23:35<3:47:02,  2.81s/it]
#   9%|8         | 461/5300 [23:38<3:46:45,  2.81s/it]
#   9%|8         | 462/5300 [23:41<3:46:24,  2.81s/it]
#   9%|8         | 463/5300 [23:44<3:55:32,  2.92s/it]
#   9%|8         | 464/5300 [23:47<3:52:26,  2.88s/it]
#   9%|8         | 465/5300 [23:49<3:50:20,  2.86s/it]
#
# {'loss': '0.01999', 'grad_norm': '0.003469', 'learning_rate': '0.000458', 'epoch': '4.387'}
#
#   9%|8         | 465/5300 [23:49<3:50:20,  2.86s/it]
#   9%|8         | 466/5300 [23:52<3:48:46,  2.84s/it]
#   9%|8         | 467/5300 [23:55<3:47:43,  2.83s/it]
#   9%|8         | 468/5300 [23:58<3:46:47,  2.82s/it]
#   9%|8         | 469/5300 [24:01<3:46:27,  2.81s/it]
#   9%|8         | 470/5300 [24:03<3:45:58,  2.81s/it]
#
# {'loss': '0.01976', 'grad_norm': '0.005883', 'learning_rate': '0.0004575', 'epoch': '4.434'}
#
#   9%|8         | 470/5300 [24:03<3:45:58,  2.81s/it]
#   9%|8         | 471/5300 [24:07<3:54:48,  2.92s/it]
#   9%|8         | 472/5300 [24:09<3:52:01,  2.88s/it]
#   9%|8         | 473/5300 [24:12<3:49:59,  2.86s/it]
#   9%|8         | 474/5300 [24:15<3:48:29,  2.84s/it]
#   9%|8         | 475/5300 [24:18<3:47:28,  2.83s/it]
#
# {'loss': '0.02007', 'grad_norm': '0.004461', 'learning_rate': '0.000457', 'epoch': '4.481'}
#
#   9%|8         | 475/5300 [24:18<3:47:28,  2.83s/it]
#   9%|8         | 476/5300 [24:21<3:46:35,  2.82s/it]
#   9%|9         | 477/5300 [24:23<3:45:58,  2.81s/it]
#   9%|9         | 478/5300 [24:26<3:45:49,  2.81s/it]
#   9%|9         | 479/5300 [24:29<3:54:45,  2.92s/it]
#   9%|9         | 480/5300 [24:32<3:51:51,  2.89s/it]
#
# {'loss': '0.01982', 'grad_norm': '0.00526', 'learning_rate': '0.0004565', 'epoch': '4.528'}
#
#   9%|9         | 480/5300 [24:32<3:51:51,  2.89s/it]
#   9%|9         | 481/5300 [24:35<3:49:48,  2.86s/it]
#   9%|9         | 482/5300 [24:38<3:48:07,  2.84s/it]
#   9%|9         | 483/5300 [24:41<3:47:10,  2.83s/it]
#   9%|9         | 484/5300 [24:43<3:46:20,  2.82s/it]
#   9%|9         | 485/5300 [24:46<3:45:39,  2.81s/it]
#
# {'loss': '0.01997', 'grad_norm': '0.008358', 'learning_rate': '0.0004561', 'epoch': '4.575'}
#
#   9%|9         | 485/5300 [24:46<3:45:39,  2.81s/it]
#   9%|9         | 486/5300 [24:49<3:45:16,  2.81s/it]
#   9%|9         | 487/5300 [24:52<3:53:33,  2.91s/it]
#   9%|9         | 488/5300 [24:55<3:50:51,  2.88s/it]
#   9%|9         | 489/5300 [24:58<3:48:49,  2.85s/it]
#   9%|9         | 490/5300 [25:01<3:47:48,  2.84s/it]
#
# {'loss': '0.0197', 'grad_norm': '0.005881', 'learning_rate': '0.0004556', 'epoch': '4.623'}
#
#   9%|9         | 490/5300 [25:01<3:47:48,  2.84s/it]
#   9%|9         | 491/5300 [25:03<3:47:12,  2.83s/it]
#   9%|9         | 492/5300 [25:06<3:46:24,  2.83s/it]
#   9%|9         | 493/5300 [25:09<3:46:09,  2.82s/it]
#   9%|9         | 494/5300 [25:12<3:45:49,  2.82s/it]
#   9%|9         | 495/5300 [25:15<3:45:43,  2.82s/it]
#
# {'loss': '0.01971', 'grad_norm': '0.01212', 'learning_rate': '0.0004551', 'epoch': '4.67'}
#
#   9%|9         | 495/5300 [25:15<3:45:43,  2.82s/it]
#   9%|9         | 496/5300 [25:18<3:55:36,  2.94s/it]
#   9%|9         | 497/5300 [25:21<3:52:28,  2.90s/it]
#   9%|9         | 498/5300 [25:23<3:50:00,  2.87s/it]
#   9%|9         | 499/5300 [25:26<3:48:01,  2.85s/it]
#   9%|9         | 500/5300 [25:29<3:46:48,  2.84s/it]
#
# {'loss': '0.01949', 'grad_norm': '0.00569', 'learning_rate': '0.0004546', 'epoch': '4.717'}
#
#   9%|9         | 500/5300 [25:29<3:46:48,  2.84s/it]
#   9%|9         | 501/5300 [25:32<3:46:28,  2.83s/it]
#   9%|9         | 502/5300 [25:35<3:45:51,  2.82s/it]
#   9%|9         | 503/5300 [25:37<3:45:06,  2.82s/it]
#  10%|9         | 504/5300 [25:41<3:53:17,  2.92s/it]
#  10%|9         | 505/5300 [25:43<3:50:40,  2.89s/it]
#
# {'loss': '0.01995', 'grad_norm': '0.007245', 'learning_rate': '0.0004542', 'epoch': '4.764'}
#
#  10%|9         | 505/5300 [25:43<3:50:40,  2.89s/it]
#  10%|9         | 506/5300 [25:46<3:48:49,  2.86s/it]
#  10%|9         | 507/5300 [25:49<3:47:10,  2.84s/it]
#  10%|9         | 508/5300 [25:52<3:46:02,  2.83s/it]
#  10%|9         | 509/5300 [25:55<3:45:16,  2.82s/it]
#  10%|9         | 510/5300 [25:57<3:44:39,  2.81s/it]
#
# {'loss': '0.02004', 'grad_norm': '0.006397', 'learning_rate': '0.0004537', 'epoch': '4.811'}
#
#  10%|9         | 510/5300 [25:57<3:44:39,  2.81s/it]
#  10%|9         | 511/5300 [26:00<3:44:14,  2.81s/it]
#  10%|9         | 512/5300 [26:03<3:53:18,  2.92s/it]
#  10%|9         | 513/5300 [26:06<3:50:10,  2.89s/it]
#  10%|9         | 514/5300 [26:09<3:48:18,  2.86s/it]
#  10%|9         | 515/5300 [26:12<3:46:49,  2.84s/it]
#
# {'loss': '0.02', 'grad_norm': '0.01049', 'learning_rate': '0.0004532', 'epoch': '4.858'}
#
#  10%|9         | 515/5300 [26:12<3:46:49,  2.84s/it]
#  10%|9         | 516/5300 [26:15<3:45:43,  2.83s/it]
#  10%|9         | 517/5300 [26:17<3:45:01,  2.82s/it]
#  10%|9         | 518/5300 [26:20<3:44:11,  2.81s/it]
#  10%|9         | 519/5300 [26:23<3:43:48,  2.81s/it]
#  10%|9         | 520/5300 [26:26<3:52:39,  2.92s/it]
#
# {'loss': '0.01995', 'grad_norm': '0.00497', 'learning_rate': '0.0004527', 'epoch': '4.906'}
#
#  10%|9         | 520/5300 [26:26<3:52:39,  2.92s/it]
#  10%|9         | 521/5300 [26:29<3:49:40,  2.88s/it]
#  10%|9         | 522/5300 [26:32<3:47:35,  2.86s/it]
#  10%|9         | 523/5300 [26:35<3:46:01,  2.84s/it]
#  10%|9         | 524/5300 [26:37<3:45:06,  2.83s/it]
#  10%|9         | 525/5300 [26:40<3:44:16,  2.82s/it]
#
# {'loss': '0.01991', 'grad_norm': '0.008134', 'learning_rate': '0.0004523', 'epoch': '4.953'}
#
#  10%|9         | 525/5300 [26:40<3:44:16,  2.82s/it]
#  10%|9         | 526/5300 [26:43<3:43:46,  2.81s/it]
#  10%|9         | 527/5300 [26:46<3:43:30,  2.81s/it]
#  10%|9         | 528/5300 [26:49<3:50:19,  2.90s/it]
#  10%|9         | 529/5300 [26:52<3:48:03,  2.87s/it]
#  10%|#         | 530/5300 [26:54<3:32:17,  2.67s/it]
#
# {'loss': '0.01986', 'grad_norm': '0.01277', 'learning_rate': '0.0004518', 'epoch': '5'}
#
#  10%|#         | 530/5300 [26:54<3:32:17,  2.67s/it]
#
#   0%|          | 0/27 [00:00<?, ?it/s]
#
#   7%|7         | 2/27 [00:00<00:05,  4.20it/s]
#
#  11%|#1        | 3/27 [00:00<00:08,  2.82it/s]
#
#  15%|#4        | 4/27 [00:01<00:09,  2.49it/s]
#
#  19%|#8        | 5/27 [00:01<00:09,  2.26it/s]
#
#  22%|##2       | 6/27 [00:02<00:09,  2.20it/s]
#
#  26%|##5       | 7/27 [00:02<00:09,  2.13it/s]
#
#  30%|##9       | 8/27 [00:03<00:08,  2.12it/s]
#
#  33%|###3      | 9/27 [00:03<00:08,  2.06it/s]
#
#  37%|###7      | 10/27 [00:04<00:08,  2.07it/s]
#
#  41%|####      | 11/27 [00:04<00:07,  2.04it/s]
#
#  44%|####4     | 12/27 [00:05<00:07,  2.05it/s]
#
#  48%|####8     | 13/27 [00:05<00:06,  2.02it/s]
#
#  52%|#####1    | 14/27 [00:06<00:06,  2.03it/s]
#
#  56%|#####5    | 15/27 [00:06<00:05,  2.02it/s]
#
#  59%|#####9    | 16/27 [00:07<00:05,  2.04it/s]
#
#  63%|######2   | 17/27 [00:07<00:04,  2.02it/s]
#
#  67%|######6   | 18/27 [00:08<00:04,  2.04it/s]
#
#  70%|#######   | 19/27 [00:08<00:03,  2.03it/s]
#
#  74%|#######4  | 20/27 [00:09<00:03,  2.04it/s]
#
#  78%|#######7  | 21/27 [00:09<00:02,  2.01it/s]
#
#  81%|########1 | 22/27 [00:10<00:02,  2.02it/s]
#
#  85%|########5 | 23/27 [00:10<00:02,  2.00it/s]
#
#  89%|########8 | 24/27 [00:11<00:01,  2.02it/s]
#
#  93%|#########2| 25/27 [00:11<00:00,  2.01it/s]
#
#  96%|#########6| 26/27 [00:12<00:00,  2.03it/s]
#
# 100%|##########| 27/27 [00:12<00:00,  2.27it/s]
#
#
#
#
# {'eval_loss': '0.01965', 'eval_runtime': '13.09', 'eval_samples_per_second': '8.024', 'eval_steps_per_second': '2.063', 'epoch': '5'}
#
#  10%|#         | 530/5300 [27:07<3:32:17,  2.67s/it]
#
# 100%|##########| 27/27 [00:12<00:00,  2.27it/s]
#
#
#
# {'train_runtime': '1629', 'train_samples_per_second': '25.97', 'train_steps_per_second': '3.254', 'train_loss': '0.07337', 'epoch': '5'}
#
#  10%|#         | 530/5300 [27:08<3:32:17,  2.67s/it]
#  10%|#         | 530/5300 [27:09<4:04:21,  3.07s/it]
# [INFO] Training done.
# TrainOutput(global_step=530, training_loss=0.07337407396649415, metrics={'train_runtime': 1628.9031, 'train_samples_per_second': 25.968, 'train_steps_per_second': 3.254, 'total_flos': 7.107449762535091e+16, 'train_loss': 0.07337407396649415, 'epoch': 5.0})
# [INFO] Best checkpoint: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\temp_training_output\checkpoint-106
# [INFO] Final run dir:   C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\runs\lr0.0005_epoch1_batchsize8
# [INFO] Saved final best LoRA to: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\runs\lr0.0005_epoch1_batchsize8\best_lora
# [INFO] Saved run info to:       C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\runs\lr0.0005_epoch1_batchsize8\run_info.json

# %% [markdown]
# ## Evaluation

# %%
import os
os.environ.setdefault("TOKENIZERS_PARALLELISM", "false")

# Disable torch.compile/inductor for this notebook eval to avoid dtype mismatches
os.environ["UNSLOTH_DISABLE_COMPILE"] = "1"
os.environ["TORCHINDUCTOR_DISABLE"] = "1"

import torch
from pathlib import Path

import unsloth
from unsloth import FastVisionModel
from peft import PeftModel

base_model_hf = "unsloth/Qwen3-VL-8B-Instruct-unsloth-bnb-4bit"
RUN_PATH = r"C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\runs\lr0.0005_epoch1_batchsize8"

run_p = Path(RUN_PATH)
lora_dir = run_p if (run_p / "adapter_config.json").exists() else (run_p / "best_lora")
assert (lora_dir / "adapter_config.json").exists(), f"Missing adapter_config.json in: {lora_dir}"
print("Using LoRA dir:", lora_dir)

model, tokenizer = FastVisionModel.from_pretrained(
    model_name=base_model_hf,
    load_in_4bit=True,
)

model = PeftModel.from_pretrained(model, str(lora_dir))

# Force inference mode and force fp16 to avoid bf16 mismatch paths
FastVisionModel.for_inference(model)
model = model.half()
model.eval()

print("Loaded Unsloth base + processor + LoRA (forced fp16, compile disabled)")
print("Device:", next(model.parameters()).device)
print("Model dtype sample:", next(model.parameters()).dtype)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# W0402 11:54:18.254000 27952 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# Unsloth: Your Flash Attention 2 installation seems to be broken?
# A possible explanation is you have a new CUDA version which isn't
# yet compatible with FA2? Please file a ticket to Unsloth or FA2.
# We shall now use Xformers instead, which does not have any performance hits!
# We found this negligible impact by benchmarking on 1x A100.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Using LoRA dir: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\runs\lr0.0005_epoch1_batchsize8\best_lora
# ==((====))==  Unsloth 2026.2.1: Fast Qwen3_Vl patching. Transformers: 5.3.0.dev0.
#    \\   /|    NVIDIA GeForce RTX 5070 Ti. Num GPUs = 1. Max memory: 15.92 GB. Platform: Windows.
# O^O/ \_/ \    Torch: 2.10.0+cu130. CUDA: 12.0. CUDA Toolkit: 13.0. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/750 [00:00<?, ?it/s]
# Loaded Unsloth base + processor + LoRA (forced fp16, compile disabled)
# Device: cuda:0
# Model dtype sample: torch.float16

# %%
import pandas as pd
from pathlib import Path

# ----- YOU SET THESE -----
eval_list_csv = r"C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\test_split.csv"
images_dir    = r"C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\images"
ext = ".png"
# -------------------------

df = pd.read_csv(eval_list_csv)
cols = set(df.columns)

# label column
label_col = None
for c in ["diagnosis", "dr_grade", "grade", "label", "y", "target", "class"]:
    if c in cols:
        label_col = c
        break
if label_col is None:
    raise ValueError(f"No label column found. Columns={df.columns.tolist()}")

# image path logic:
# - if image_path exists: use it (if relative, join images_dir)
# - else: use filename or id_code and build the path
if "image_path" in cols:
    def to_abs(p):
        p = str(p)
        pp = Path(p)
        return str(pp) if pp.is_absolute() else str(Path(images_dir) / p)
    df["image_path"] = df["image_path"].astype(str).map(to_abs)

else:
    id_col = None
    for c in ["filename", "id_code", "image", "image_id", "file", "path"]:
        if c in cols:
            id_col = c
            break
    if id_col is None:
        raise ValueError(f"No image id/path column found. Columns={df.columns.tolist()}")

    def build_path(v):
        v = str(v)
        pv = Path(v)
        if pv.is_absolute():
            return str(pv)
        if pv.suffix == "":
            return str(Path(images_dir) / f"{v}{ext}")
        return str(Path(images_dir) / v)

    df["image_path"] = df[id_col].astype(str).map(build_path)

df["y_true"] = df[label_col].astype(int)

df_list = df[["image_path", "y_true"]].copy()
missing = df_list["image_path"].map(lambda p: not Path(p).exists()).sum()
print("Rows:", len(df_list), "| Missing image files:", int(missing))

if missing:
    df_list = df_list[df_list["image_path"].map(lambda p: Path(p).exists())].reset_index(drop=True)
    print("After dropping missing:", len(df_list))
# Out:
# Rows: 106 | Missing image files: 0

# %%
import numpy as np
from PIL import Image
import torch

INSTRUCTION = (
    "You are a medical imaging assistant.\n"
    "Grade diabetic retinopathy severity from this retinal fundus image.\n\n"
    "Scale:\n"
    "0 - No DR\n"
    "1 - Mild\n"
    "2 - Moderate\n"
    "3 - Severe\n"
    "4 - Proliferative DR\n\n"
    "Return exactly this format:\n"
    "<answer>X - LABEL</answer>"
)

CANDIDATES = [
    "<answer>0 - No DR</answer>",
    "<answer>1 - Mild</answer>",
    "<answer>2 - Moderate</answer>",
    "<answer>3 - Severe</answer>",
    "<answer>4 - Proliferative DR</answer>",
]

def probs_by_full_answer_logprob(image_path: str) -> np.ndarray:
    img = Image.open(image_path).convert("RGB")

    prompt_messages = [{
        "role": "user",
        "content": [
            {"type": "text", "text": INSTRUCTION},
            {"type": "image", "image": img},
        ],
    }]

    prompt_only_text = tokenizer.apply_chat_template(
        prompt_messages, tokenize=False, add_generation_prompt=True
    )

    prompt_only = tokenizer(images=img, text=prompt_only_text, return_tensors="pt").to(model.device)
    # ---- ADD THIS (1) ----
    if "pixel_values" in prompt_only:
        prompt_only["pixel_values"] = prompt_only["pixel_values"].to(dtype=torch.float16)
    # ----------------------
    prompt_len = prompt_only["input_ids"].shape[1]

    scores = []
    with torch.no_grad():
        for cand in CANDIDATES:
            messages = prompt_messages + [
                {"role": "assistant", "content": [{"type": "text", "text": cand}]}
            ]
            full_text = tokenizer.apply_chat_template(
                messages, tokenize=False, add_generation_prompt=False
            )

            batch = tokenizer(images=img, text=full_text, return_tensors="pt").to(model.device)
            # ---- ADD THIS (2) ----
            if "pixel_values" in batch:
                batch["pixel_values"] = batch["pixel_values"].to(dtype=torch.float16)
            # ----------------------

            labels = batch["input_ids"].clone()
            labels[:, :prompt_len] = -100

            # If you already did model = model.half(), you can just do:
            out = model(**batch, labels=labels)

            n = int((labels != -100).sum().item())
            total_logprob = -float(out.loss.item()) * max(n, 1)
            scores.append(total_logprob)

    scores = np.array(scores, dtype=np.float64)
    scores = scores - scores.max()
    probs = np.exp(scores) / np.exp(scores).sum()
    return probs

# %%
import pandas as pd
import numpy as np

preds_csv = str(Path(eval_list_csv).with_name("preds_with_probs_quick.csv"))

df_run = df_list.head(30).copy()

rows = []
for idx, r in df_run.iterrows():
    probs = probs_by_full_answer_logprob(r["image_path"])
    y_pred = int(np.argmax(probs))

    row = {"image_path": r["image_path"], "y_true": int(r["y_true"]), "y_pred": y_pred}
    for k in range(5):
        row[f"p{k}"] = float(probs[k])
    rows.append(row)

    if (len(rows) % 10) == 0:
        print("Processed", len(rows), "/", len(df_run))

pd.DataFrame(rows).to_csv(preds_csv, index=False)
print("Saved:", preds_csv)
# Out:
# Processed 10 / 30
# Processed 20 / 30
# Processed 30 / 30
# Saved: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\preds_with_probs_quick.csv

# %%
import pandas as pd
import numpy as np
from pathlib import Path

preds_csv = str(Path(eval_list_csv).with_name("preds_with_probs.csv"))

rows = []
for idx, r in df_list.iterrows():
    probs = probs_by_full_answer_logprob(r["image_path"])
    y_pred = int(np.argmax(probs))

    row = {"image_path": r["image_path"], "y_true": int(r["y_true"]), "y_pred": y_pred}
    for k in range(5):
        row[f"p{k}"] = float(probs[k])
    rows.append(row)

    if (idx + 1) % 20 == 0:
        print(f"Processed {idx+1}/{len(df_list)}")

df_preds = pd.DataFrame(rows)
df_preds.to_csv(preds_csv, index=False)
print("Saved:", preds_csv)
# Out:
# Processed 20/106
# Processed 40/106
# Processed 60/106
# Processed 80/106
# Processed 100/106
# Saved: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\preds_with_probs.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    cohen_kappa_score,
    roc_curve,
    auc,
    roc_auc_score,
)
from sklearn.preprocessing import label_binarize

df_preds = pd.read_csv(preds_csv)

y_true = df_preds["y_true"].astype(int).to_numpy()
y_score = df_preds[[f"p{i}" for i in range(5)]].to_numpy()
y_pred = y_score.argmax(axis=1)

acc = accuracy_score(y_true, y_pred)
qwk = cohen_kappa_score(y_true, y_pred, weights="quadratic")
cm = confusion_matrix(y_true, y_pred, labels=[0, 1, 2, 3, 4])

print("\nAccuracy:", round(acc, 4))
print("QWK:", round(qwk, 4))
print("\nConfusion matrix (rows=true, cols=pred):\n", cm)
print(
    "\nClassification report:\n",
    classification_report(y_true, y_pred, labels=[0, 1, 2, 3, 4], digits=4),
)

# Confusion matrix image
class_names = [
    "0: Normal",
    "1: Mild",
    "2: Moderate",
    "3: Severe",
    "4: Proliferative",
]

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, interpolation="nearest", cmap="Blues")
fig.colorbar(im, ax=ax)

ax.set_title("Test Set Confusion Matrix", fontsize=18, pad=14)
ax.set_xlabel("Predicted Grade (VLM Output)", fontsize=15)
ax.set_ylabel("True Grade (Ground Truth)", fontsize=15)

ax.set_xticks(np.arange(len(class_names)))
ax.set_yticks(np.arange(len(class_names)))
ax.set_xticklabels(class_names, rotation=45, ha="right", fontsize=12)
ax.set_yticklabels(class_names, rotation=90, va="center", fontsize=12)

threshold = cm.max() / 2.0 if cm.size else 0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(
            j,
            i,
            f"{cm[i, j]}",
            ha="center",
            va="center",
            color="white" if cm[i, j] > threshold else "black",
            fontsize=11,
        )

fig.tight_layout()
cm_img_path = Path(preds_csv).with_name("confusion_matrix.png")
plt.savefig(cm_img_path, dpi=300, bbox_inches="tight")
plt.show()

print(f"Saved confusion matrix image to: {cm_img_path}")

# ROC curves (OvR)
y_true_oh = label_binarize(y_true, classes=[0, 1, 2, 3, 4])

plt.figure(figsize=(8, 6))
for i in range(5):
    if len(np.unique(y_true_oh[:, i])) < 2:
        continue
    fpr, tpr, _ = roc_curve(y_true_oh[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC={roc_auc:.3f})")

plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves (One-vs-Rest) - DR (0..4)")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()

# Macro AUC
aucs = []
for i in range(5):
    if len(np.unique(y_true_oh[:, i])) < 2:
        continue
    aucs.append(roc_auc_score(y_true_oh[:, i], y_score[:, i]))

macro_ovr_auc = float(np.mean(aucs)) if len(aucs) else float("nan")

report = classification_report(
    y_true,
    y_pred,
    labels=[0, 1, 2, 3, 4],
    digits=4,
    output_dict=True,
)

print("\n--- Summary (Macro / DR) ---")
print(f"Accuracy:      {acc:.4f}")
print(f"QWK:           {qwk:.4f}")
print(f"AUC-ROC:       {macro_ovr_auc:.4f}")
print(f"Precision:     {report['macro avg']['precision']:.4f}")
print(f"Recall:        {report['macro avg']['recall']:.4f}")
print(f"F1 Score:      {report['macro avg']['f1-score']:.4f}")
# Out:
# Accuracy: 0.5943
# QWK: 0.6497
#
# Confusion matrix (rows=true, cols=pred):
#  [[51  0  2  0  0]
#  [19  0  1  0  0]
#  [ 7  0  6 11  0]
#  [ 1  0  0  6  0]
#  [ 1  0  1  0  0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.6456    0.9623    0.7727        53
#            1     0.0000    0.0000    0.0000        20
#            2     0.6000    0.2500    0.3529        24
#            3     0.3529    0.8571    0.5000         7
#            4     0.0000    0.0000    0.0000         2
#
#     accuracy                         0.5943       106
#    macro avg     0.3197    0.4139    0.3251       106
# weighted avg     0.4819    0.5943    0.4993       106
# D:\anaconda3\envs\py311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# D:\anaconda3\envs\py311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# D:\anaconda3\envs\py311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Saved confusion matrix image to: C:\Users\Mohammad\Downloads\DR_Messidor_Only_512_Full_Dataset\Res_512\Split_80_10_10\confusion_matrix.png
# --- Summary (Macro / DR) ---
# Accuracy:      0.5943
# QWK:           0.6497
# AUC-ROC:       0.7607
# Precision:     0.3197
# Recall:        0.4139
# F1 Score:      0.3251
# D:\anaconda3\envs\py311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# D:\anaconda3\envs\py311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# D:\anaconda3\envs\py311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
